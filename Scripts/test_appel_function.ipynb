# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().resolve().parent))

import functions as ff

a = [10, 15,10,36,21,12,15, 18, 20, 25]
print("testmean(a):",ff.mean(a))
print("testmedian(a):", ff.median(a))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       5
#       6 import functions as ff
#       7
#       8 a = [10, 15,10,36,21,12,15, 18, 20, 25]
# ----> 9 print("testmean(a):",ff.mean(a))
#      10 print("testmedian(a):", ff.median(a))
#
# AttributeError: module 'functions' has no attribute 'mean'
